# %% [markdown]
# # Estrutura de Dados
#
# ### Estrutura de dados em python é simples, mas poderoso, e é extremamente importante para progamadores de dados
#
# ## Estrutura de Dados que Estudaresmos:
#
# * Tupla
# * Lista
# * Dicionário

# %% [markdown]
# ## Tupla
#
# ### Tupla é uma estrutura imutavel, ou seja os dados dessa estrutura não são alterados, não pode mudar, segue o exemplo em código abaixo

# %%
tupla = ('string')

print(tupla)
# Out:
# string

# %% [markdown]
# ### Podemos converter em sequencia ou interagir usando a função *tuple*

# %%
tup = tuple(tupla)
tup
# Out:
# ('s', 't', 'r', 'i', 'n', 'g')

# %% [markdown]
# ### É possivel acessar o elemento em uma tupla, igual o exemplo em baixo (obseverção o index em python começa com [0])

# %%
tup[0]
# Out:
# 's'

# %% [markdown]
# ### Ao definir tuplas dentro de expressões mais complicadas, geralmente é necessário colocar os valores entre parênteses, como neste exemplo de criação de uma tupla de tuplas

# %%
tupla_dentro_tupla = ((4,5,6),(7,8))

print(tupla_dentro_tupla[0])
print(tupla_dentro_tupla[1])
# Out:
# (4, 5, 6)
# (7, 8)

# %% [markdown]
# ### Se há um objeto mutável em uma tupla, pode alterar esse objeto

# %%
tup = tuple(['foo', [1, 2], True])

tup[1].append(3)
print(tup)
# Out:
# ('foo', [1, 2, 3], True)

# %% [markdown]
# ### É possivel concatenar uma tupla

# %%
(4, None, 'foo') + (6, 0) + ('bar',)
# Out:
# (4, None, 'foo', 6, 0, 'bar')

# %% [markdown]
# ### É possivel fazer copias concatenando o conteudo dentro

# %%
( 'foo', 'bar')*4
# Out:
# ('foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'bar')

# %% [markdown]
# ## Lista
#
# ### Diferente da tupla, a lista é mutavel e não possui um tamanho definido, em python é usada por *[]* e há a função list
